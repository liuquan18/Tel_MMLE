# %%
import xarray as xr
import proplot as pplt
import numpy as np
import pandas as pd

# %%
zg_processed = xr.open_dataset("/work/mh0033/m300883/Tel_MMLE/data/CESM1_CAM5/zg_processed/zg_Amon_CESM1-CAM5_historical_rcp85_r1i1p1_192001-210012.nc")

# %%
zg_processed.sel(time = "1921-03",plev = 85000).zg.plot()

# %%
zg_processed.sel(time = "1921-03",plev = 20000).zg.plot()
