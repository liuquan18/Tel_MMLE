# %%
import xarray as xr

# %%
ex = xr.open_dataset("/work/mh0033/m300883/3rdPanel/data/influence/t2min/onepct0002_echam6_echam.nc")

# %%
ex
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 149, bnds: 2, lon: 192, lat: 96)
# Coordinates:
#   * time       (time) float64 1.851e+07 1.852e+07 ... 1.998e+07 1.999e+07
#   * lon        (lon) float64 0.0 1.875 3.75 5.625 ... 352.5 354.4 356.2 358.1
#   * lat        (lat) float64 88.57 86.72 84.86 83.0 ... -84.86 -86.72 -88.57
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) float64 ...
#     var201     (time, lat, lon) float32 ...
#     var202     (time, lat, lon) float32 ...
# Attributes:
#     CDI:                       Climate Data Interface version 2.0.6 (https://...
#     Conventions:               CF-1.6
#     institution:               Max Planck Institute for Meteorology
#     frequency:                 year
#     history:                   Wed Jan 04 15:53:18 2023: cdo -P 48 -f nc -yea...
#     CDO:                       Climate Data Operators version 2.0.6 (https://...
#     cdo_openmp_thread_number:  48

# %%
ex.isel(time = 0).var202.plot()

# %%
ex.isel(time = 0).var202.mean()
# Out:
# <xarray.DataArray 'var202' ()>
# array(271.04163, dtype=float32)
# Coordinates:
#     time     float64 1.851e+07

# %%
ex.isel(time = 0).var201.mean()
# Out:
# <xarray.DataArray 'var201' ()>
# array(281.14624, dtype=float32)
# Coordinates:
#     time     float64 1.851e+07

# %%
ex.isel(time = 0).var201.plot()
